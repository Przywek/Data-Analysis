# %%
import pandas as pd 
from pandas import Series,DataFrame
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
import pandas_datareader.data as web
import pandas_datareader as pdr
from datetime import datetime

# %%
AAPL = pd.read_csv("aapl.us.txt", encoding='cp1251', sep=',')

# %%
GOOG = pd.read_csv("goog.us.txt", encoding='cp1251', sep=',')

# %%
MSFT = pd.read_csv("msft.us.txt", encoding='cp1251', sep=',')

# %%
AMZN = pd.read_csv("amzn.us.txt", encoding='cp1251', sep=',')

# %%
tech_list = [AAPL,GOOG,MSFT,AMZN]
for tech in tech_list: 
    time_series = DataFrame(data=tech['Close'])
    time_series.index = tech['Date']
    time_series.sort_index(inplace=True,ascending=True)
    time_series.index = pd.to_datetime(time_series.index)
    tech.set_index(time_series.index.values,inplace=True)
    tech.drop(columns=['Date'],inplace=True)

# %%
AAPL.head()
# Out:
#                Open     High      Low    Close    Volume  OpenInt
# 1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0
# 1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0
# 1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0
# 1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0
# 1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0

# %%
mask = (AAPL.index > '2015-01-01') & (AAPL.index <= '2017-11-10')
mask1 = (MSFT.index > '2015-01-01') & (MSFT.index <= '2017-11-10')
mask2 = (GOOG.index > '2015-01-01') & (GOOG.index <= '2017-11-10')
mask3 = (AMZN.index > '2015-01-01') & (AMZN.index <= '2017-11-10')

# %%
AAPL=AAPL.loc[mask]
MSFT=MSFT.loc[mask1]
GOOG=GOOG.loc[mask2]
AMZN=AMZN.loc[mask3]

# %%
AAPL['Close'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
AMZN['Close'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
GOOG['Close'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
MSFT['Close'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
AAPL['Volume'].plot(legend=True,figsize=(20,8))
plt.show()

# %%
AMZN['Volume'].plot(legend=True,figsize=(20,8))
plt.show()

# %%
GOOG['Volume'].plot(legend=True,figsize=(20,8))
plt.show()

# %%
MSFT['Volume'].plot(legend=True,figsize=(20,8))
plt.show()

# %%
ma_day=[10,20,50]
for ma in ma_day:
    column_name = "Ma for %s days"%(str(ma))
    AAPL[column_name] = pd.rolling_mean(AAPL['Close'],ma)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,center=False).mean()
#   after removing the cwd from sys.path.
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
#   after removing the cwd from sys.path.
# ...

# %%
for ma in ma_day:
    column_name = "Ma for %s days"%(str(ma))
    AMZN[column_name] = pd.rolling_mean(AMZN['Close'],ma)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
# ...

# %%
for ma in ma_day:
    column_name = "Ma for %s days"%(str(ma))
    GOOG[column_name] = pd.rolling_mean(GOOG['Close'],ma)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
# ...

# %%
for ma in ma_day:
    column_name = "Ma for %s days"%(str(ma))
    MSFT[column_name] = pd.rolling_mean(MSFT['Close'],ma)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10,center=False).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
# ...

# %%
AAPL[['Close','Ma for 10 days','Ma for 20 days','Ma for 50 days']].plot(subplots=False,figsize=(20,8))

# %%
AMZN[['Close','Ma for 10 days','Ma for 20 days','Ma for 50 days']].plot(subplots=False,figsize=(20,8))

# %%
GOOG[['Close','Ma for 10 days','Ma for 20 days','Ma for 50 days']].plot(subplots=False,figsize=(20,8))

# %%
MSFT[['Close','Ma for 10 days','Ma for 20 days','Ma for 50 days']].plot(subplots=False,figsize=(20,8))

# %%
AAPL.tail()
# Out:
#               Open    High     Low   Close    Volume  OpenInt  Ma for 10 days  \
# 2017-11-06  171.75  174.36  171.10  173.63  34901241        0         164.557
# 2017-11-07  173.29  174.51  173.29  174.18  24424877        0         166.321
# 2017-11-08  174.03  175.61  173.71  175.61  24451166        0         168.297
# 2017-11-09  174.48  175.46  172.52  175.25  29533086        0         170.137
# 2017-11-10  175.11  175.38  174.27  174.67  25130494        0         171.357
#
#             Ma for 20 days  Ma for 50 days
# 2017-11-06        160.6945        158.5822
# 2017-11-07        161.6365        158.8480
# 2017-11-08        162.6175        159.1136
# 2017-11-09        163.6080        159.3634
# 2017-11-10        164.5200        159.5886

# %%
AAPL['Daily Return'] = AAPL['Close'].pct_change()
AAPL['Daily Return'].plot(figsize=(10,4), legend=True)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
AMZN['Daily Return'] = AMZN['Close'].pct_change()
AMZN['Daily Return'].plot(figsize=(10,4), legend=True)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
GOOG['Daily Return'] = GOOG['Close'].pct_change()
GOOG['Daily Return'].plot(figsize=(10,4), legend=True)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
MSFT['Daily Return'] = MSFT['Close'].pct_change()
MSFT['Daily Return'].plot(figsize=(10,4), legend=True)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.distplot(AAPL['Daily Return'].dropna(),bins=100,color='green')

# %%
sns.distplot(AMZN['Daily Return'].dropna(),bins=100,color='purple')

# %%
sns.distplot(GOOG['Daily Return'].dropna(),bins=100,color='orange')

# %%
sns.distplot(MSFT['Daily Return'].dropna(),bins=100,color='blue')

# %%
AAPL['Daily Return'].hist()

# %%
AMZN['Daily Return'].hist()

# %%
GOOG['Daily Return'].hist()

# %%
MSFT['Daily Return'].hist()

# %%
tech_list1 = ['AAPL','GOOG','MSFT','AMZN']
start = datetime(2016,1,1)
end = datetime(2017,11,10)
closing_df = web.DataReader(tech_list1,'yahoo',start,end)['Adj Close']

# %%
closing_df.head()
# Out:
#                   AAPL         AMZN         GOOG       MSFT
# Date
# 2017-11-10  173.960739  1125.349976  1028.069946  83.060730
# 2017-11-09  174.538391  1129.130005  1031.260010  83.278603
# 2017-11-08  174.895645  1132.880005  1039.849976  83.744064
# 2017-11-07  173.476532  1123.170044  1033.329956  83.456863
# 2017-11-06  172.920822  1120.660034  1025.900024  83.654938

# %%
tech_rets = closing_df.pct_change()

# %%
sns.jointplot('GOOG','GOOG',data=tech_rets,kind='scatter',color='seagreen')

# %%
sns.jointplot('GOOG','MSFT',tech_rets,kind='scatter')

# %%
sns.pairplot(tech_rets.dropna())

# %%
returns_fig = sns.PairGrid(tech_rets.dropna())
returns_fig.map_upper(plt.scatter,cmap='purple')
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig.map_diag(plt.hist,bins=30)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
returns_fig_1 = sns.PairGrid(closing_df.dropna())
returns_fig_1.map_upper(plt.scatter,cmap='purple')
returns_fig_1.map_lower(sns.kdeplot,cmap='cool_d')
returns_fig_1.map_diag(plt.hist,bins=30)
# Out:
# /home/przywek/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
corr = tech_rets.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(600, -200, as_cmap=True)
sns.heatmap(corr, mask=mask,cmap=cmap, annot=True, vmin=0.4,vmax=.7, center=0,
            square=True, linewidths=.2, cbar_kws={"shrink": .5})

# %%
rets = tech_rets.dropna()
area = np.pi*20

# %%
plt.scatter(rets.mean(),rets.std(),s = area)
plt.xlabel('Expected returns')
plt.ylabel('Risk')

for label,x,y in zip(rets.columns,rets.mean(),rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.3'))

# %%
sns.distplot(AAPL['Daily Return'].dropna(), bins=100,color='purple')

# %%
rets.head()
# Out:
#                 AAPL      AMZN      GOOG      MSFT
# Date
# 2017-11-09  0.003321  0.003359  0.003103  0.002623
# 2017-11-08  0.002047  0.003321  0.008330  0.005589
# 2017-11-07 -0.008114 -0.008571 -0.006270 -0.003430
# 2017-11-06 -0.003203 -0.002235 -0.007190  0.002373
# 2017-11-03 -0.010043 -0.008085  0.006414 -0.003907

# %%
rets['AAPL'].quantile(0.05)
# Out:
# -0.019579672228551125

# %%
days=365
dt = 1/days
mu = rets.mean()['GOOG']
sigma = rets.std()['GOOG']

# %%
def stock_monte_carlo(start_price,days,mu,sigma):
    price = np.zeros(days)
    price[0] = start_price
    shock = np.zeros(days)
    drift = np.zeros(days)
    for x in range(1,days):
        shock[x] = np.random.normal(loc=mu*dt,scale=sigma*np.sqrt(dt))
        drift[x] = mu*dt
        price[x] = price[x-1] + (price[x-1]*(drift[x]+shock[x]))
    return price

# %%
GOOG.head()
# Out:
#               Open    High     Low   Close   Volume  OpenInt  Ma for 10 days  \
# 2015-01-02  529.01  531.27  524.10  524.81  1446432        0             NaN
# 2015-01-05  523.26  524.33  513.06  513.87  2052886        0             NaN
# 2015-01-06  515.00  516.17  501.05  501.96  2891303        0             NaN
# 2015-01-07  507.00  507.24  499.65  501.10  2059169        0             NaN
# 2015-01-08  497.99  503.48  491.00  502.68  3344104        0             NaN
#
#             Ma for 20 days  Ma for 50 days  Daily Return
# 2015-01-02             NaN             NaN           NaN
# 2015-01-05             NaN             NaN     -0.020846
# 2015-01-06             NaN             NaN     -0.023177
# 2015-01-07             NaN             NaN     -0.001713
# 2015-01-08             NaN             NaN      0.003153

# %%
start_price = 529.01
for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
    plt.xlabel('Days')
    plt.ylabel('Price')
    plt.title('Monte Carlo Analysis for Google')

# %%
runs = 1000
simulations = np.zeros(runs)
for run in range(runs):
    simulations[run]= stock_monte_carlo(start_price,days,mu,sigma)[days-1]

# %%
q = np.percentile(simulations,1)
plt.hist(simulations,bins=200)
plt.figtext(0.6,0.8,s="Start price: $%.2f" %start_price)
plt.figtext(0.6,0.7,"Mean final price: $%.2f" % simulations.mean())
plt.figtext(0.6,0.6,"VaR(0.99): $%.2f" % (start_price - q,))
plt.figtext(0.6,0.5,"VaR(0.99): $%.2f" % q)
plt.axvline(x=q,linewidth=4,color='r')
plt.title(u"Final price distribution for Google Stock after %s days" % days,weight='bold');
