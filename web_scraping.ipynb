# %%
from bs4 import BeautifulSoup 
import pandas as pd 
from pandas import Series, DataFrame
import urllib.request
import urllib.parse

# %%
email = []
firma = []
telefon = []
opis = []
cat = []

# %%
url = 'https://www.pkt.pl/szukaj/wrocław/70'
url = urllib.parse.urlsplit(url)
url = list(url)
url[2] = urllib.parse.quote(url[2])
url = urllib.parse.urlunsplit(url)
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page,"lxml")

# %%
comp = soup.find_all("div",class_="box-content company-row list-sel ")
for item in comp:
    e_mail = item.find("div",class_="call-cell call--email")
    if not e_mail:
        email.append("N/A")
    else:
        email.append(e_mail.find("span")["title"])
    nazwa = item.find("h2",class_="company-name")
    if not nazwa:
        firma.append("N/A")
    else:
        firma.append(nazwa.text)
    tele = item.find("div", class_="call-cell call--phone")
    if not tele:
        telefon.append("N/A")
    else:
        telefon.append(tele.find("a")['data-phone'])
    x = item.find("div", class_="company-snippet")
    if not x:
        opis.append("N/A")
    else:
        opis.append(x.text)
    y = item.find("div", class_="company-category")
    if not y:
        cat.append("N/A")
    else:
        cat.append(y.text)
compv1 = soup.find_all("div",class_="box-content company-row ")
for item in compv1:
    e_mail = item.find("div",class_="call-cell call--email")
    if not e_mail:
        email.append("N/A")
    else:
        email.append(e_mail.find("span")["title"])
    nazwa = item.find("h2",class_="company-name")
    if not nazwa:
        firma.append("N/A")
    else:
        firma.append(nazwa.text)
    tele = item.find("div", class_="call-cell call--phone")
    if not tele:
        telefon.append("N/A")
    else:
        telefon.append(tele.find("a")['data-phone'])
    x = item.find("div", class_="company-snippet")
    if not x:
        opis.append("N/A")
    else:
        opis.append(x.text)
    y = item.find("div", class_="company-category")
    if not y:
        cat.append("N/A")
    else:
        cat.append(y.text)
compv2 = soup.find_all("div",class_="box-content company-row list-free")
for item in compv2:
    e_mail = item.find("div",class_="call-cell call--email")
    if not e_mail:
        email.append("N/A")
    else:
        email.append(e_mail.find("span")["title"])
    nazwa = item.find("h2",class_="company-name")
    if not nazwa:
        firma.append("N/A")
    else:
        firma.append(nazwa.text)
    tele = item.find("div", class_="call-cell call--phone")
    if not tele:
        telefon.append("N/A")
    else:
        telefon.append(tele.find("a")['data-phone'])
    x = item.find("div", class_="company-snippet")
    if not x:
        opis.append("N/A")
    else:
        opis.append(x.text)
    y = item.find("div", class_="company-category")
    if not y:
        cat.append("N/A")
    else:
        cat.append(y.text)

# %%
firma = Series(firma)
email = Series(email)
telefon = Series(telefon)
opis = Series(opis)
cat = Series(cat)
Baza = pd.concat([ firma, cat, opis, telefon, email],axis=1)

# %%
Baza.columns=['Nazwa_Firmy', 'Kategria', 'Opis', 'Telefon', 'Email']
Baza
# Out:
#                                             Nazwa_Firmy  \
# 0     Anna Paszta Inter-Bus. Przewozy busami Niemcy,...
# 1                 Notariusz Wrocław Wojciech Czyniewski
# 2     Pogotowie zamkowe Wrocław Awaryjne otwieranie ...
# 3                            Kliniki Ziemlewski Wrocław
# 4     Anna Oryńska, Stanisław Oryński. Przewodnicy t...
# 5     Anna Paszta Inter-Bus. Przewozy busami Niemcy,...
# 1731  Zarząd Geodezji, Kartografii i Katastru Miejsk...
#
#                                                Kategria  \
# 0                                     Transport osobowy
# 1                                            Notariusze
# 2                                            Ślusarstwo
# 3                                   Medycyna estetyczna
# 4                               Przewodnicy turystyczni
# 5                                Autobusy i przewoźnicy
# 6                                 Transport samochodowy
# 7                  Sprzedaż, wynajem i serwis autobusów
# 8                               Przewodnicy turystyczni
# 9                                         Biura podróży
# 10                               Instalacje elektryczne
# 11                                        Nieruchomości
# 12                   Pomoc drogowa i holowanie pojazdów
# 13                                           Ślusarstwo
# 14                                           Ślusarstwo
# 15                      Wypożyczanie maszyn budowlanych
# 16                      Wypożyczanie maszyn budowlanych
# 17                                      Farby i lakiery
# 18                                            Drukarnie
# 19                   Usługi geodezyjne i kartograficzne
# 20                                      Artykuły gumowe
# 21                                           Wentylacja
# 22                                 Księgowi i rewidenci
# 23    Wyposażenie gabinetów lekarskich i stomatologi...
# 24                                   Opakowania foliowe
# 25                                           Notariusze
# 26                                               Hotele
# 27                                 Chirurgia plastyczna
# 28                                  Taśmy samoprzylepne
# 29                                Malarstwo artystyczne
# ...                                                 ...
# 1702                          Podnośniki i transportery
# 1703                       Zarządzanie nieruchomościami
# 1704                                 Usługi protetyczne
# 1705              Stowarzyszenia, towarzystwa i związki
# 1706                                      Nieruchomości
# 1707                       Szyby, reflektory i lusterka
# 1708                          Parki, ogrody i rezerwaty
# 1709          Organizacja imprez sportowych i rekreacji
# 1710              Stowarzyszenia, towarzystwa i związki
# 1711              Stowarzyszenia, towarzystwa i związki
# 1712              Stowarzyszenia, towarzystwa i związki
# 1713              Stowarzyszenia, towarzystwa i związki
# 1714              Stowarzyszenia, towarzystwa i związki
# 1715              Stowarzyszenia, towarzystwa i związki
# 1716                Izby zawodowe i cechy rzemieślnicze
# 1717                Izby zawodowe i cechy rzemieślnicze
# 1718                Izby zawodowe i cechy rzemieślnicze
# 1719                Izby zawodowe i cechy rzemieślnicze
# 1720                                   Usługi budowlane
# 1721                                      Nieruchomości
# 1722                                   Żłobki publiczne
# 1723                                Usługi transportowe
# 1724                                               Okna
# 1725                                        Naprawa AGD
# 1726                               Usługi fotograficzne
# 1727                       Wydobywcy i sprzedawcy węgla
# 1728                                   Nadzór budowlany
# 1729                                       Stomatolodzy
# 1730                                   Biura rachunkowe
# 1731                                Urzędy miast i gmin
#
#                                                    Opis       Telefon  \
# 0     Firma Inter-Bus w Mirostowicach Dolnych to doś...  68 375 05 14
# 1     Siedziba naszej kancelarii notarialnej znajduj...  71 372 38 46
# 2     Działalność firmy ABC Zabezpieczeń z powodzeni...   512 600 708
# 3     ... dlatego zapewniają elastyczne podejście. D...  71 348 22 66
# 4     Serdecznie zapraszamy do zapoznania się z nasz...   502 291 465
# 5     Chcesz wynająć busa na imprezę? Musisz dostać ...  68 375 05 14
# 6     Do przewozu osób osób wykorzystujemy wyłącznie...  68 375 05 14
# 7     Firma Inter-Bus w Mirostowicach Dolnych od poc...  68 375 05 14
# 9               biuro@przygodabt.com.pl
# 10          biuro@elektryk24-wroclaw.pl
# 11                                  N/A
# 12                 k.szymitko@gmail.com
# 13                                  N/A
# 14                                  N/A
# 15                  wroclaw@ramirent.pl
# 16                 wroclaw1@ramirent.pl
# 17                       kosta@kosta.pl
# 18                      argi@wr.home.pl
# 19                jbezdzietny@gmail.com
# 20                     guma@guma.com.pl
# 21             centrowent@centrowent.pl
# 22                       biuro@tax-2.pl
# 23    rejestracja@margo-stomatologia.pl
# 24                wroclaw@techno.com.pl
# 25                    feszgrubiak@op.pl
# 26                      hotel@haston.pl
# 27            knakiewicz@knakiewicz.com
# 28                 info@duo-strzelin.pl
# 29              teresa@profiterm.com.pl
# ...                                 ...
# 1702                                N/A
# 1703                     wroclaw@zzn.pl
# 1704                                N/A
# 1705              hufiec@wroclaw.zhp.pl
# 1706                                N/A
# 1707                                N/A
# 1708        zoo-sekretariat@zoo.wroc.pl
# 1709                                N/A
# 1710                                N/A
# 1711                                N/A
# 1712                                N/A
# 1713                        znpsm@wp.pl
# 1714                                N/A
# 1715                                N/A
# 1716                                N/A
# 1717                                N/A
# 1718                                N/A
# 1719                                N/A
# 1720              bachmat.wroclaw@wp.pl
# 1721                                N/A
# 1722                spzoz@spzoz.wroc.pl
# 1723              kontakt@busekspres.pl
# 1724                   fabryka@empol.pl
# 1725           kubikkrzysztof@poczta.fm
# 1726              info@midoribrands.com
# 1727                      p.major@wp.pl
# 1728                pinb.pow.wroc@vp.pl
# 1729                  wroclaw@salvus.eu
# 1730                    jsalamon1@wp.pl
# 1731         sekretariat@zgkikm.wroc.pl
#
# [1732 rows x 5 columns]

# %%
Baza = Baza[Baza.Telefon != "N/A"]
Baza = Baza.drop_duplicates(subset=["Nazwa_Firmy"],keep='first')
Baza = Baza.reset_index(drop=True)

# %%
Baza.to_csv('baza_firm.csv', encoding='utf-8')

# %%
telefon
# Out:
# ['68 375 05 14',
#  '71 372 38 46',
#  '512 600 708',
#  '71 348 22 66',
#  '502 291 465',
#  '68 375 05 14',
#  '68 375 05 14',
#  '68 375 05 14',
#  '510 913 855',
#  '52 355 91 11',
#  '886 604 684',
#  '604 248 855',
#  '664 035 390',
#  '505 616 000',
#  '505 616 000',
#  '607 171 249',
#  '71 363 50 23',
#  '33 854 28 93',
#  '71 789 92 19',
#  '609 145 510',
#  '71 325 41 00',
#  '71 333 65 60',
#  '71 328 35 49',
#  '71 796 09 99',
#  '71 342 26 45',
#  '604 248 855',
#  '71 322 55 00',
#  '71 328 44 44',
#  '71 381 21 32',
#  '601 805 690',
#  '539 731 852',
#  '605 620 034',
#  '605 066 160',
#  '609 145 510',
#  '796 454 097',
#  '713 723 846',
#  '71 361 46 81',
#  '77 416 28 61',
#  '71 796 09 99',
#  '71 341 34 66',
#  '71 360 04 81',
#  '71 343 83 88',
#  '71 344 96 03',
#  '91 578 36 76',
#  '693 542 803',
#  '600 214 900',
#  '71 347 65 35',
#  '71 373 43 46',
#  '71 325 86 82',
#  '71 325 86 82']
